# %% [markdown]
# <a href="https://colab.research.google.com/github/ElisandroJr/aulaprogramacao/blob/main/Funcoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Exercicios**
# 1. Crie uma chamada potencia(n, expo) que rcebe um numero e o exponte e retorna o valor da exponenciação
# 2. Faça uma função area(base, altura), que calcula a area de um retangulo.
# 3. Execreva uma função que calcule o IMC de um individuo, recebendo o peso e a altura.
# 4. Crie uma função que aplica um descontoa um preço dado em um produto e de o valor final com desconto.

# %%
def potencia(n, expo):
  return n ** expo

print(potencia(3, 4))
# Out:
# 81

# %%
def area(base, altura):
  forma = verificaForma(base, altura)
  if forma == 0:
    return f'A área do retângulo é {base * altura}'
  else:
    return f'A área do quadrado é {base * altura}'

def verificaForma(base, altura):
  if base == altura:  #se for quadrado 1, se for retangulo 0
    return 1
  else:
    return 0

print (area(6, 6))
# Out:
# A área do quadrado é 36

# %%
### IMC < 19.5 - magro
### 18.5 < IMC - eutotrofico
### 25.0 < IMC - sobrepeso
### IMC > 30 - obeso

# %%
def IMC(peso, altura):
    return peso / (altura ** 2)


def classificaIMC(peso, altura):
  valorIMC = IMC(peso, altura)
  if (valorIMC > 30):
    return 'obeso'
  elif (valorIMC > 25):
    return 'sobrepeso'
  elif (valorIMC > 18.5):
    return 'Eutotrófico'
  else:
    return 'magro'

# %%
peso = float(input('Digite o peso: '))
altura = float(input('Digite a altura: '))
print (classificaIMC(60, 1.95))
# Out:
# Digite o peso: 25
# Digite a altura: 1.25
# magro

# %%
#Crie outra funcao que verifique se a
#figura e um  quadrado ou um retangulo,
# e dapois calcula sua area
